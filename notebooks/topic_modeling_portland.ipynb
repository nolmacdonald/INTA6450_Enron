# %% [markdown]
# # PORTLAND TOPIC MODELING

# %%
import numpy as np
import pandas as pd
import re
import sqlite3
import matplotlib.pyplot as plt
# NLP with the LDA model for topic modeling
from gensim.corpora import Dictionary
from gensim.models import LdaModel, LdaMulticore
from gensim.models.coherencemodel import CoherenceModel
# Visualize the topics
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
from bs4 import BeautifulSoup
import sqlite3

# %% [markdown]
# # Processed Database

# %%
# Connect to the database (or create it if it doesn't exist)
connection = sqlite3.connect("../data/emails_processed.db")

# Create a cursor object to execute SQL commands
cursor = connection.cursor()

# Load the dataframe from the SQLite database
emails_df = pd.read_sql_query("SELECT * FROM emails_processed", connection)

# Close the connection
connection.close()

# Show email data
emails_df.head()
# Out:
#                                                 text  \
# 0  ---------------------- Forwarded by Rika Imai/...
# 1                                              great
# 2  oohh la la.  who was your "friend"?  did you g...
# 3  \nAttached are the two files with this week's ...
# 4  lm:\nWhat are your thoughts going forward........
#
#                                       message_id  \
# 0     <88180.1075863689140.JavaMail.evans@thyme>
# 1   <4460514.1075857469666.JavaMail.evans@thyme>
# 2   <2160301.1075858147494.JavaMail.evans@thyme>
# 3  <22847680.1075863611080.JavaMail.evans@thyme>
# 4  <15012282.1075852957298.JavaMail.evans@thyme>
#
#                                     date                       from  \
# 0   Tue, 8 May 2001 08:37:00 -0700 (PDT)        rika.imai@enron.com
# 1  Wed, 21 Jun 2000 02:01:00 -0700 (PDT)   hunter.shively@enron.com
# 2  Wed, 16 Aug 2000 03:03:00 -0700 (PDT)  matthew.lenhart@enron.com
# 3  Wed, 15 Aug 2001 05:46:47 -0700 (PDT)        rika.imai@enron.com
# 4   Wed, 3 Oct 2001 00:35:05 -0700 (PDT)  jennifer.fraser@enron.com
#
#                                                   to  \
# 0  john.forney@enron.com, mike.carson@enron.com, ...
# 1                          richard.tomaski@enron.com
# 2                                shelliott@dttus.com
# 3  russell.ballato@enron.com, hicham.benjelloun@e...
# 4                                larry.may@enron.com
#
#                         subject cc bcc mime-version  \
# 0      4 Month Rolling Forecast                 1.0
# 1               Re: Jim Simpson                 1.0
# 2                    Re: Re[2]:                 1.0
# 3  FW: Nuclear Rolling Forecast                 1.0
# 4                         hello                 1.0
#
#                          content-type  ... x-bcc  \
# 0  text/plain; charset=ANSI_X3.4-1968  ...
# 1        text/plain; charset=us-ascii  ...
# 2        text/plain; charset=us-ascii  ...
# 3        text/plain; charset=us-ascii  ...
# 4        text/plain; charset=us-ascii  ...
#
#                                            folder     origin  \
# 0   \Rob_Benson_Jun2001\Notes Folders\Notes inbox   Benson-R
# 1      \Hunter_Shively_Jun2001\Notes Folders\Sent  Shively-H
# 2     \Matthew_Lenhart_Jun2001\Notes Folders\Sent  Lenhart-M
# 3  \ExMerge - Benson, Robert\Inbox\Large Messages   BENSON-R
# 4                   \LMAY2 (Non-Privileged)\Inbox      May-L
#
#                      filename priority  \
# 0                 rbenson.nsf   normal
# 1                 hshivel.nsf   normal
# 2                 mlenhar.nsf   normal
# 3      rob benson 6-25-02.PST   normal
# 4  LMAY2 (Non-Privileged).pst   normal
#
#                                       processed_text  \
# 0   forwarded by rika imainaenron on   pm dan sal...
# 1                                              great
# 2  oohh la la  who was your friend  did you guys ...
# 3  attached are the two files with this weeks nuc...
# 4  lmwhat are your thoughts going forward also wh...
#
#                                               tokens  \
# 0  ["['forward',", "'rika',", "'imainaenron',", "...
# 1                                      ["['great']"]
# 2  ["['oohh',", "'la',", "'la',", "'friend',", "'...
# 3  ["['attach',", "'two',", "'file',", "'week',",...
# 4  ["['lmwhat',", "'thought',", "'go',", "'forwar...
#
#                stripped_date             datetime dominant_topic
# 0   Tue, 8 May 2001 08:37:00  2001-05-08 08:37:00              8
# 1  Wed, 21 Jun 2000 02:01:00  2000-06-21 02:01:00              6
# 2  Wed, 16 Aug 2000 03:03:00  2000-08-16 03:03:00              2
# 3  Wed, 15 Aug 2001 05:46:47  2001-08-15 05:46:47              5
# 4   Wed, 3 Oct 2001 00:35:05  2001-10-03 00:35:05              0
#
# [5 rows x 24 columns]

# %% [markdown]
# # Filter Emails
#
# - Filter emails sent to employees with `portland` in the email address

# %%
# emails_df["processed_text"] = emails_df["text"].apply(extract_text)
emails_df = emails_df[emails_df["to"].str.contains(r".*portland.*@enron.com", case=False, na=False)]

# %% [markdown]
# # Preparation

# %%
emails_df['tokens'] = emails_df['tokens'].apply(lambda x: x.split())

# Create a dictionary and a corpus
dictionary = Dictionary(emails_df['tokens'])
corpus = [dictionary.doc2bow(tokens) for tokens in emails_df['tokens']]

# %% [markdown]
# # LDA Model

# %%
# Number of topics
num_topics = 5

# Train the LDA model
# lda_model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, passes=10, random_state=42)
lda_model = LdaMulticore(corpus=corpus, id2word=dictionary, num_topics=num_topics, passes=1000, random_state=42, workers=6)

# %%
# Print topics
for idx, topic in lda_model.print_topics(-1):
    print(f"Topic {idx}: {topic}")
# Out:
# Topic 0: 0.023*""'mw',"," + 0.014*""'schedul',"," + 0.014*""'deal',"," + 0.013*""'pleas',"," + 0.009*""'price',"," + 0.009*""'need',"," + 0.009*""'call',"," + 0.008*""'time',"," + 0.007*""'make',"," + 0.007*""'sell',","
# Topic 1: 0.011*""'enron',"," + 0.008*""'pleas',"," + 0.007*""'work',"," + 0.007*""'new',"," + 0.006*""'join',"," + 0.006*""'portland',"," + 0.006*""'us',"," + 0.005*""'email',"," + 0.005*""'park',"," + 0.005*""'compani',","
# Topic 2: 0.077*""'term',"," + 0.073*""'epmi',"," + 0.061*""'p',"," + 0.045*""'short',"," + 0.039*""'total',"," + 0.035*""'long',"," + 0.028*""'california',"," + 0.026*""'northwest',"," + 0.026*""'southwest',"," + 0.026*""'palo',","
# Topic 3: 0.016*""'enron',"," + 0.009*""'pleas',"," + 0.006*""'team',"," + 0.006*""'question',"," + 0.005*""'pm',"," + 0.005*""'work',"," + 0.005*""'employe',"," + 0.005*""'meet',"," + 0.005*""'provid',"," + 0.005*""'would',","
# Topic 4: 0.014*""'trade',"," + 0.011*""'inform',"," + 0.009*""'market',"," + 0.009*""'report',"," + 0.009*""'posit',"," + 0.008*""'manag',"," + 0.008*""'group',"," + 0.007*""'power',"," + 0.007*""'custom',"," + 0.007*""'servic',","

# %% [markdown]
# # Coherence

# %%
# Compute Coherence Score (c_v)
coherence_model_lda = CoherenceModel(model=lda_model, texts=emails_df['tokens'], dictionary=dictionary, coherence='c_v', processes=6)
coherence_score = coherence_model_lda.get_coherence()
print(f"Coherence Score (c_v): {coherence_score}")
# Out:
# Coherence Score (c_v): 0.5035425310078454

# %% [markdown]
# # Ranked Topics

# %%
# Step 1: Calculate topic importance (weights)
topic_importance = [0] * lda_model.num_topics
for doc in corpus:
    for topic_id, weight in lda_model[doc]:
        topic_importance[topic_id] += weight
topic_importance = [weight / len(corpus) for weight in topic_importance]  # Normalize by number of documents

# Step 2: Combine importance and terms into a DataFrame
num_words = 10  # Number of top words to show per topic
ranked_topics_data = []

for topic_id, importance in enumerate(topic_importance):
    topic_terms = lda_model.print_topic(topic_id, topn=num_words)
    ranked_topics_data.append({
        'Topic': topic_id,
        'Importance': importance,
        'Terms': topic_terms
    })

# Create DataFrame and sort by importance
ranked_topics_df = pd.DataFrame(ranked_topics_data).sort_values(by='Importance', ascending=False)
ranked_topics_df
# Out:
#    Topic  Importance                                              Terms
# 0      0    0.397583  0.023*""'mw',"," + 0.014*""'schedul',"," + 0.0...
# 3      3    0.218154  0.016*""'enron',"," + 0.009*""'pleas',"," + 0....
# 1      1    0.187429  0.011*""'enron',"," + 0.008*""'pleas',"," + 0....
# 4      4    0.126463  0.014*""'trade',"," + 0.011*""'inform',"," + 0...
# 2      2    0.060127  0.077*""'term',"," + 0.073*""'epmi',"," + 0.06...

# %% [markdown]
# - The first 3 topics reference energy with `mw` and `stwbom`
# - Markets, trading, merger, palo verde, southwest, power common

# %%
# Add new columns for each term and weight
for i in range(1, num_words + 1):
    ranked_topics_df[f'Term {i}'] = None
    ranked_topics_df[f'Term {i} Weight'] = None

# Populate the new columns with terms and weights
for idx, row in ranked_topics_df.iterrows():
    terms_weights = row['Terms'].split(' + ')
    for i, term_weight in enumerate(terms_weights):
        weight, term = term_weight.split('*')
        ranked_topics_df.at[idx, f'Term {i+1}'] = term.strip("'\",")
        ranked_topics_df.at[idx, f'Term {i+1} Weight'] = float(weight)

ranked_topics_df.reset_index(inplace=True, drop=True)
ranked_topics_df.to_csv("../data/ranked_topics.csv", index=False)
ranked_topics_df
# Out:
#    Topic  Importance                                              Terms  \
# 0      0    0.397583  0.023*""'mw',"," + 0.014*""'schedul',"," + 0.0...
# 1      3    0.218154  0.016*""'enron',"," + 0.009*""'pleas',"," + 0....
# 2      1    0.187429  0.011*""'enron',"," + 0.008*""'pleas',"," + 0....
# 3      4    0.126463  0.014*""'trade',"," + 0.011*""'inform',"," + 0...
# 4      2    0.060127  0.077*""'term',"," + 0.073*""'epmi',"," + 0.06...
#
#   Term 1 Term 1 Weight   Term 2 Term 2 Weight  Term 3 Term 3 Weight    Term 4  \
# 0     mw         0.023  schedul         0.014    deal         0.014     pleas
# 1  enron         0.016    pleas         0.009    team         0.006  question
# 2  enron         0.011    pleas         0.008    work         0.007       new
# 3  trade         0.014   inform         0.011  market         0.009    report
# 4   term         0.077     epmi         0.073       p         0.061     short
#
#    ...    Term 6 Term 6 Weight      Term 7 Term 7 Weight     Term 8  \
# 0  ...      need         0.009        call         0.009       time
# 1  ...      work         0.005     employe         0.005       meet
# 2  ...  portland         0.006          us         0.006      email
# 3  ...     manag         0.008       group         0.008      power
# 4  ...      long         0.035  california         0.028  northwest
#
#   Term 8 Weight     Term 9 Term 9 Weight  Term 10 Term 10 Weight
# 0         0.008       make         0.007     sell          0.007
# 1         0.005     provid         0.005    would          0.005
# 2         0.005       park         0.005  compani          0.005
# 3         0.007     custom         0.007   servic          0.007
# 4         0.026  southwest         0.026     palo          0.026
#
# [5 rows x 23 columns]

# %% [markdown]
# # Dominant Topic

# %%
def get_dominant_topic(lda_model, corpus):
    dominant_topics = []
    for doc_bow in corpus:
        topic_probs = lda_model.get_document_topics(doc_bow)
        dominant_topic = max(topic_probs, key=lambda x: x[1])[0]
        dominant_topics.append(dominant_topic)
    return dominant_topics

emails_df['dominant_topic'] = get_dominant_topic(lda_model, corpus)
# Showing that dominant_topic is added to the DataFrame and contains an integer value
emails_df['dominant_topic']
# Out:
# 132       0
# 366       0
# 444       0
# 547       1
# 686       1
#          ..
# 250245    0
# 250455    3
# 250758    1
# 250898    3
# 250906    4
# Name: dominant_topic, Length: 1572, dtype: int64

# %% [markdown]
# # Visualize

# %%
# Save the model
lda_model.save('enron_lda_model')

# Visualize
vis = gensimvis.prepare(lda_model, corpus, dictionary)

# Save as HTML
pyLDAvis.save_html(vis, 'lda_viz_portland.html')

# Show
pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el77237129456712165328177930" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el77237129456712165328177930_data = {"mdsDat": {"x": [-0.034951882238709084, -0.13454058964736687, -0.08636475130394625, -0.11981597881342751, 0.3756732020034492], "y": [0.21784372882048633, -0.028688388294098074, -0.0780534392100733, -0.0782080382977154, -0.032893863018599576], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [30.280671804189563, 23.304752629184154, 17.919294405373535, 17.35527152611521, 11.140009635137536]}, "tinfo": {"Term": ["\"'term',\",", "\"'epmi',\",", "\"'p',\",", "\"'short',\",", "\"'total',\",", "\"'long',\",", "\"'mw',\",", "\"'northwest',\",", "\"'california',\",", "\"'palo',\",", "\"'southwest',\",", "\"'deal',\",", "\"'sp',\",", "\"'next',\",", "\"'mwh',\",", "\"'day',\",", "\"'mid',\",", "\"'op',\",", "\"'c',\",", "\"'np',\",", "\"'enron',\",", "\"'q',\",", "\"'grand',\",", "\"'real',\",", "\"'schedul',\",", "\"'desk',\",", "\"'nov',\",", "\"'cut',\",", "\"'enpow',\",", "\"'time',\",", "\"'mw',\",", "\"'epe',\",", "\"'bpa',\",", "\"'el',\",", "\"'paso',\",", "\"'stwbom',\",", "\"'path',\",", "\"'stsw',\",", "\"'pv',\",", "\"'sc',\",", "\"'length',\",", "\"'rt',\",", "\"'px',\",", "\"'pac',\",", "\"'harbor',\",", "\"'output',\",", "\"'apx',\",", "\"'cut',\",", "\"'ciso',\",", "\"'enrol',\",", "\"'stcali',\",", "\"'congest',\",", "\"'stwhourli',\",", "\"'resuppli',\",", "\"'tie',\",", "\"'questionsthanksk']\"]", "\"'index',\",", "\"'ncpa',